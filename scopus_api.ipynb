# %% [markdown]
# ## Examples of retrieving data from Scopus using Scopus API and Elsapy
# Elsapy: https://github.com/ElsevierDev/elsapy (Requres Python 3.x)
# Elsevier Scopus APIs https://dev.elsevier.com/sc_apis.html

# %%
#pip install elsapy

# %%
from elsapy.elsclient import ElsClient
from elsapy.elssearch import ElsSearch
from elsapy.elsprofile import ElsAuthor
from elsapy.elsdoc import AbsDoc
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import json

# %% [markdown]
# ### 1. Define some functions that we will use later

# %%
def affiliation_id_serch(schoolname, client):
    """Search affiliation ID by name
    client - object of the ElsClient class  """
    
    school_srch = ElsSearch(' AFFIL(%s)'%schoolname,'affiliation')
    school_srch.execute(client)
    return school_srch.results

def search_auth_by_name(fstname, lstname, schoolid, client):
    """Find author's Scopus ID by first, last name and affiliation ID.
    In case of an error, perform search without affiliation ID and return first author in the serach result
    """
    auth_srch = ElsSearch('AUTHLASTNAME(%s)'%lstname + ' AUTHFIRST(%s)'%fstname + ' AF-ID(%s)'%schoolid,'author')
    auth_srch.execute(client)

    #print ("auth_srch has", len(auth_srch.results), "results.")
    authorfound = auth_srch.results[0]
    
    if 'error' in authorfound.keys():
        status = 'error'
        auth_srch = ElsSearch('AUTHLASTNAME(%s)'%lstname + ' AUTHFIRST(%s)'%fstname ,'author')
        auth_srch.execute(client)

        #print ("auth_srch has", len(auth_srch.results), "results.")
        authorfound = auth_srch.results[0]
        if 'error' in authorfound.keys():
            status = 'error'
            return status, {}
        if 'affiliation-current' in authorfound.keys():
            if authorfound['affiliation-current']['affiliation-id']!=schoolid:
                status = 'new-affil'
            else:
                status = 'success'
        else:
            print(fstname, lstname, ' --- can not find affiliation-current in keys')
            status = 'warning'
    else:
        status = 'success'
    
    return status, authorfound

def auth_metrics(auth_id, client):
    """Read author metrics for a given Scopus author ID auth_id
    client - object of the ElsClient class 
    reurns status, author data, total number of paers, citations and h-index """
    
    my_auth = ElsAuthor(uri = 'https://api.elsevier.com/content/author/author_id/'+auth_id) 

    if my_auth.read(client):
        status = 'success'
    else:
        status = 'error'
        return status, None, None, None, None
    
    my_auth.read_metrics(client)

    if my_auth._data==None:
        npapers, ncitation, hindex = None, None, None
        status = 'error'
    else:
        status = 'success'
        
        npapers = my_auth._data['coredata']['document-count']
        ncitation = my_auth._data['coredata']['citation-count']
        hindex = my_auth._data['h-index']
        
    return status,my_auth._data, npapers, ncitation, hindex

def author_pubs(author_id, client):
    """
    Obtain publication list for a given Scopus author ID author_id
    client - object of the ElsClient class
    returns publication list and full output of the ElsSearch search request
    """
    doc_srch = ElsSearch('AU-ID(%s)'%author_id,'scopus')
    doc_srch.execute(client, get_all = True)

  
    pubs = []
    for rslt in doc_srch.results:
               
        year = rslt['prism:coverDate'].split('-')[0]
        citedby = rslt['citedby-count']
        scopusid = rslt['dc:identifier'].split(':')[1]
        title = rslt['dc:title']
        jrnlname = rslt['prism:publicationName']
        pubs.append({'year':year, 'cited':citedby, 'scopusid': scopusid, 'title': title,'jrnlname': jrnlname})
 
    return pubs, doc_srch.results

# %% [markdown]
# ## 2. Initialize client (object of the ElsClient class) with your apikey

# %%
apikey = '7762f59ce3b9cb9117c74958bab4202b' # insert a valid apikey

## Initialize client
client = ElsClient(apikey)
client.inst_token = '' # leave it blank unless you have it

# %% [markdown]
# ## 3. Find a unique Scopus affiliation ID for a school of interest

# %%
school_srch_results = affiliation_id_serch('um6p', client)

print('Found ', len(school_srch_results), ' schools \n')

print('{:<15} {:>}'.format('Affiliation ID', '| Afiiliation Name'))
print('-'*40)

for school in school_srch_results:
    school_id =  school['dc:identifier'].split(':')[1]
    school_name = school['affiliation-name']
    print( '{:<15}  {:>}'.format(school_id, school_name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 school_srch_results = affiliation_id_serch('um6p', client)
#       3 print('Found ', len(school_srch_results), ' schools \n')
#       5 print('{:<15} {:>}'.format('Affiliation ID', '| Afiiliation Name'))
#
# NameError: name 'client' is not defined

# %% [markdown]
# ##### Search resulted in 25 different affiliations. First one is the one we want

# %%
school = school_srch_results[0]

#keep Scopus ID in the school_id variable
school_id = school['dc:identifier'].split(':')[1]
school_name = school['affiliation-name']

# %% [markdown]
# Here is other information we already know about this school from the search result

# %%
school
# Out:
# {'@_fa': 'true',
#  'link': [{'@_fa': 'true',
#    '@ref': 'self',
#    '@href': 'https://api.elsevier.com/content/affiliation/affiliation_id/60192082'},
#   {'@_fa': 'true',
#    '@ref': 'search',
#    '@href': 'https://api.elsevier.com/content/search/scopus?query=af-id%2860192082%29'},
#   {'@_fa': 'true',
#    '@ref': 'scopus-affiliation',
#    '@href': 'https://www.scopus.com/affil/profile.uri?afid=60192082&partnerID=HzOxMe3b&origin=inward'}],
#  'prism:url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60192082',
#  'dc:identifier': 'AFFILIATION_ID:60192082',
#  'eid': '10-s2.0-60192082',
#  'affiliation-name': 'Mohammed VI Polytechnic University',
#  'name-variant': [{'@_fa': 'true', '$': 'Mohammed Vi Polytechnic University'}],
#  'document-count': '4575',
#  'city': 'Ben Guerir',
#  'country': 'Morocco',
#  'parent-affiliation-id': '0'}

# %% [markdown]
# ## 4. Find author by last and firsrt name and obtain his unique Scopus ID

# %%
first_name = 'Gérard'
last_name = 'Bruno'

auth_srch = ElsSearch('AUTHLASTNAME(%s)'%last_name + ' AUTHFIRST(%s)'%first_name,'author')
auth_srch.execute(client)

print ("Found ", len(auth_srch.results), " authors \n")
authorfound = auth_srch.results[0]

print('{:<6} {:<6} {:<12} {:<15} {:>}'.format('First name |', 'Last name |', 'Scopus ID |', 'Affil ID', '| Affil name'))
print('-'*80)
for author in auth_srch.results:
    #let's look on every author and print the name and affiliaiton stored in Scopus  
    author_id = author['dc:identifier'].split(':')[1]
    first_name_scopus = author['preferred-name']['given-name']
    last_name_scopus = author['preferred-name']['surname']
    affil_name = author['affiliation-current']['affiliation-name']
    affil_id = author['affiliation-current']['affiliation-id']
#     print(author)
    print('{:<12} {:<11} {:<14} {:<14} {:>}'.format(first_name_scopus, last_name_scopus, author_id, affil_id, affil_name))
# Out:
# Found  5  authors
#
# First name | Last name | Scopus ID |  Affil ID        | Affil name
# --------------------------------------------------------------------------------
# Bruno        Lebon       55148141500    60020623       Brunel University London
# Gérard       Bruno       57197151789    60029640       European Commission
# Gerard       Bruno       7202704772     60021160       Cleveland Clinic Foundation
# Gérard       Bruno       23481439900    60123163       INRAE
# Gerard J.    Bruno       22933342400    60029833       University of Oklahoma Health Sciences Center

# %%
# Specify the Scopus ID of the author you want to search for
scopus_id = '8963275500'  # Replace 'AUTHOR_ID_HERE' with the actual Scopus ID

# Perform the search using the Scopus ID
auth_srch = ElsSearch('AU-ID(%s)' % scopus_id, 'author')
auth_srch.execute(client)

print("Found ", len(auth_srch.results), " authors \n")

print('{:<12} {:<12} {:<12} {:<15} {:>}'.format('First name |', 'Last name |', 'Scopus ID |', 'Affil ID', '| Affil name'))
print('-'*80)
for author in auth_srch.results:
    author_id = author['dc:identifier'].split(':')[1]
    first_name_scopus = author['preferred-name']['given-name']
    last_name_scopus = author['preferred-name']['surname']
    affil_name = author['affiliation-current']['affiliation-name']
    affil_id = author['affiliation-current']['affiliation-id']
    print('{:<12} {:<12} {:<12} {:<15} {:>}'.format(first_name_scopus, last_name_scopus, author_id, affil_id, affil_name))
# Out:
# Found  1  authors
#
# First name | Last name |  Scopus ID |  Affil ID        | Affil name
# --------------------------------------------------------------------------------
# Ismaïl       Berrada      8963275500   60192082        Mohammed VI Polytechnic University

# %% [markdown]
# #### We are looking for author number 4 in the above list.
# #### We can select him manulay or specify a shool name or school affiliation ID in the search query

# %%
last_name = 'Morozov'
first_name = 'Yurii'
school_id = '60021508'

auth_srch = ElsSearch('AUTHLASTNAME(%s)'%last_name + ' AUTHFIRST(%s)'%first_name + ' AF-ID(%s)'%school_id, 'author')
auth_srch.execute(client)

print ("Found ", len(auth_srch.results), " authors ")
authorfound = auth_srch.results[0]

for author in auth_srch.results:
    #let's look on every author and print the name and affiliaiton stored in Scopus  
    author_id = author['dc:identifier'].split(':')[1]
    first_name_scopus = author['preferred-name']['given-name']
    last_name_scopus = author['preferred-name']['surname']
    affil_name = author['affiliation-current']['affiliation-name']
    affil_id = author['affiliation-current']['affiliation-id']
    
    print('{:<12} {:<11} {:<14} {:<14} {:>}'.format(first_name_scopus, last_name_scopus, author_id, affil_id, affil_name))
# Out:
# Found  1  authors
# Yurii V.     Morozov     55966498300    60021508       University of Notre Dame

# %% [markdown]
# This looks better.
# Keep in mind however, that if author's current affiliation ID is different from the one specified in the request, search will result in error.

# %% [markdown]
# #### Lets look what other information about the author we already know

# %%
author
# Out:
# {'@_fa': 'true',
#  'link': [{'@_fa': 'true',
#    '@ref': 'self',
#    '@href': 'https://api.elsevier.com/content/author/author_id/55966498300'},
#   {'@_fa': 'true',
#    '@ref': 'search',
#    '@href': 'https://api.elsevier.com/content/search/author?query=au-id%2855966498300%29'},
#   {'@_fa': 'true',
#    '@ref': 'scopus-citedby',
#    '@href': 'https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55966498300&origin=inward'},
#   {'@_fa': 'true',
#    '@ref': 'scopus-author',
#    '@href': 'https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55966498300&origin=inward'}],
#  'prism:url': 'https://api.elsevier.com/content/author/author_id/55966498300',
#  'dc:identifier': 'AUTHOR_ID:55966498300',
#  'eid': '9-s2.0-55966498300',
#  'preferred-name': {'surname': 'Morozov',
#   'given-name': 'Yurii V.',
#   'initials': 'Y.V.'},
#  'name-variant': [{'@_fa': 'true',
#    'surname': 'Morozov',
#    'given-name': 'Yurii',
#    'initials': 'Y.'}],
#  'document-count': '17',
#  'subject-area': [{'@abbrev': 'ENER', '@frequency': '12', '$': 'Energy (all)'},
#   {'@abbrev': 'CHEM', '@frequency': '11', '$': 'Chemistry (all)'},
#   {'@abbrev': 'MATE', '@frequency': '11', '$': 'Materials Science (all)'}],
#  'affiliation-current': {'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021508',
#   'affiliation-id': '60021508',
#   'affiliation-name': 'University of Notre Dame',
#   'affiliation-city': 'Notre Dame',
#   'affiliation-country': 'United States'}}

# %% [markdown]
# #### As you can see, search result dictionary contains number of publications for a given author accesible via 'document-count' key

# %%
print("Author", author['preferred-name']['given-name'], author['preferred-name']['surname'], "has", author['document-count'], " publications")
print("Scopus ID:", author['dc:identifier'].split(':')[1])
# Out:
# Author Yurii V. Morozov has 17  publications
# Scopus ID: 55966498300

# %%
first_name = 'Yurii'
last_name = 'Morozov'
school_id = '60021508'

search_auth_by_name(first_name, last_name, school_id, client)
# Out:
# ('success',
#  {'@_fa': 'true',
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/author/author_id/55966498300'},
#    {'@_fa': 'true',
#     '@ref': 'search',
#     '@href': 'https://api.elsevier.com/content/search/author?query=au-id%2855966498300%29'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-citedby',
#     '@href': 'https://www.scopus.com/author/citedby.uri?partnerID=HzOxMe3b&citedAuthorId=55966498300&origin=inward'},
#    {'@_fa': 'true',
#     '@ref': 'scopus-author',
#     '@href': 'https://www.scopus.com/authid/detail.uri?partnerID=HzOxMe3b&authorId=55966498300&origin=inward'}],
#   'prism:url': 'https://api.elsevier.com/content/author/author_id/55966498300',
#   'dc:identifier': 'AUTHOR_ID:55966498300',
#   'eid': '9-s2.0-55966498300',
#   'preferred-name': {'surname': 'Morozov',
#    'given-name': 'Yurii V.',
#    'initials': 'Y.V.'},
#   'name-variant': [{'@_fa': 'true',
#     'surname': 'Morozov',
#     'given-name': 'Yurii',
#     'initials': 'Y.'}],
#   'document-count': '17',
#   'subject-area': [{'@abbrev': 'ENER',
#     '@frequency': '12',
#     '$': 'Energy (all)'},
#    {'@abbrev': 'MATE', '@frequency': '10', '$': 'Materials Science (all)'},
#    {'@abbrev': 'CHEM', '@frequency': '10', '$': 'Chemistry (all)'}],
#   'affiliation-current': {'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021508',
#    'affiliation-id': '60021508',
#    'affiliation-name': 'University of Notre Dame',
#    'affiliation-city': 'Notre Dame',
#    'affiliation-country': 'United States'}})

# %% [markdown]
# #### In the following example we will try to find author's Scopus ID using his last and first names and affiliation ID.
# #### And in case of an error, perform a search only with first and last name. Use *search_auth_by_name()* function defined in the beginning.

# %%
fstname = 'Zachary'
lstname = 'Schultz'
school_id = '60021508'

status, author  = search_auth_by_name(fstname, lstname, school_id, client)

print('provided affiliation ID ', school_id)
print('Search status =', status)
print('Current affiliation = ', author['affiliation-current']['affiliation-name'], author['affiliation-current']['affiliation-id'])

print("Author",author['preferred-name']['given-name'], author['preferred-name']['surname'], "has", author['document-count'], " publications")
print("Scopus ID:", author['dc:identifier'].split(':')[1])
# Out:
# provided affiliation ID  60021508
# Search status = success
# Current affiliation =  University of Notre Dame 60021508
# Author Zachary D. Schultz has 105  publications
# Scopus ID: 6506722050

# %% [markdown]
# Satus 'new-affil' means that author was not found with provided affiliation id

# %% [markdown]
# ## 5. Obtain number of publications, citation count, and h-index for a given author

# %%
affil_name = author['affiliation-current']['affiliation-name']

# %%
author_scopus_id = '8963275500'
status, search_result, npubs, ncits, hindex = auth_metrics(author_scopus_id, client)

print(search_result['author-profile']['preferred-name']['given-name'], search_result['author-profile']['preferred-name']['surname'])
print("Number of publications %i."%npubs, "Citations %i."%ncits, " h-index %i."%hindex)
# Out:
# Ismaïl Berrada
# Number of publications 75. Citations 448.  h-index 10.

# %% [markdown]
# ##### As perviously dictionary search_result contains more information about the author such as affiliation history, name variants, journals author has publications, etc.
# ##### Below is the list of dicitonary keys

# %%
search_result.keys()
# Out:
# dict_keys(['@status', '@_fa', 'coredata', 'affiliation-current', 'affiliation-history', 'subject-areas', 'author-profile', 'h-index'])

# %% [markdown]
# ##### Among others, I found useful 'publication-range' in 'author-profile' providing interval of years when current author published papers

# %%
search_result['author-profile']['publication-range']
# Out:
# {'@end': '2020', '@start': '2013'}

# %% [markdown]
# ## 6. Obtain list of publications for a given author using author's Scopus ID

# %%
author_scopus_id = '8963275500'
publications, full_result = author_pubs(author_scopus_id, client)

# %%
#publications

# %%
df = pd.DataFrame(publications)
df.head(5)

# %%
df= df[['title','year','cited']]
df

# %%
#df.to_csv('ttt.csv')

# %%
#df = pd.read_csv('scopus1.csv')
#df= df[['Title','Year','Cited by']]
# Transform the DataFrame to text
#text_list = df.apply(lambda row: f"The paper titled '{row['Title']}' from the year {row['Year']} was cited {row['Cited by']} times.", axis=1).tolist()
#text = "\n".join(text_list)
#text
# Out:
# 'The paper titled \'Analysis of the dissolution of phosphate ore particles in phosphoric acid: Influence of particle size distribution\' from the year 2024 was cited 0 times.\nThe paper titled \'Copper phosphorylated cellulose nanofibers mediated azide-alkyne cycloaddition click reaction in water\' from the year 2024 was cited 0 times.\nThe paper titled \'Novel technique for the preparation and analysis of powder-based polished sections by automated optical Mineralogy: Part 1 – Comparative study of representativity\' from the year 2023 was cited 0 times.\nThe paper titled \'Reaction mechanism of thermal decomposition of Phosphogypsum\' from the year 2023 was cited 0 times.\nThe paper titled \'Recovery of rare earth elements and sulfuric acid solution from phosphate byproducts via hydrofluoric acid conversion\' from the year 2023 was cited 2 times.\nThe paper titled \'Effect of alkaline leaching of phosphogypsum on sulfate reduction activity and bacterial community composition using different sources of anaerobic microbial inoculum\' from the year 2023 was cited 1 times.\nThe paper titled \'Unraveling the consequences of nitrogen addition on soil phosphorus fractions in alpine grasslands: insights from field experiments and global analysis\' from the year 2023 was cited 0 times.\nThe paper titled \'Investigating the magneto-transport and thermal properties of 2D electron systems under the influence of the Aharonov–Bohm field and Eckart potential interaction\' from the year 2024 was cited 0 times.\nThe paper titled \'Counter-attack of biocontrol agents: Environmentally benign Approaches against Root-knot nematodes (Meloidogyne spp.) on Agricultural crops\' from the year 2023 was cited 0 times.\nThe paper titled \'Correction: UPLC–ESI–QTOF–MS profiling, antioxidant, antidiabetic, antibacterial, anti-inflammatory, antiproliferative activities and\xa0in\xa0silico molecular docking analysis of\xa0Barleria strigosa (Chemical and Biological Technologies in Agriculture, (2023), 10, 1, (73), 10.1186/s40538-023-00451-2)\' from the year 2023 was cited 0 times.\nThe paper titled \'Comparing approaches for a multi-level planning problem in a mining industry\' from the year 2023 was cited 0 times.\nThe paper titled \'Author Correction: Influence of El Niño on the variability of global shoreline position (Nature Communications, (2023), 14, 1, (3133), 10.1038/s41467-023-38742-9)\' from the year 2023 was cited 0 times.\nThe paper titled \'Physiological responses of three field-grown species (Ceratonia siliqua, Eucalyptus camaldulensis, and Moringa oleifera) to water deficits in a Mediterranean semi-arid climate\' from the year 2023 was cited 1 times.\nThe paper titled \'Distance education as a tool to improve researchers’ knowledge on predatory journals in countries with limited resources: the Moroccan experience\' from the year 2023 was cited 2 times.\nThe paper titled \'XRF online analyzer for measurements of P2O5 content in phosphate slurry\' from the year 2023 was cited 0 times.\nThe paper titled \'Quantification of ciprofloxacin in pharmaceutical products from various brands using FT-NIR: A comparative investigation of PLS and MCR-ALS\' from the year 2023 was cited 0 times.\nThe paper titled \'ZnO intercalated into graphene oxide based 2-D binary composite for improved thermal properties using as a potential nanofluid\' from the year 2023 was cited 0 times.\nThe paper titled \'From by-product to sustainable building material: Reusing phosphate washing sludge for eco-friendly red brick production\' from the year 2023 was cited 0 times.\nThe paper titled \'Evaluating greenhouse gas mitigation through alternate wetting and drying irrigation in Colombian rice production\' from the year 2024 was cited 0 times.\nThe paper titled \'Forecasting solar energy production: A comparative study of machine learning algorithms\' from the year 2023 was cited 0 times.\nThe paper titled \'Experimental investigation of the variation of the local gas velocitie ...

# %%
# Transform the DataFrame to text
text_list = df.apply(lambda row: f"The paper titled '{row['title']}' from the year {row['year']} was cited {row['cited']} times.", axis=1).tolist()
text = "\n".join(text_list)
text
# Out:
# 'The paper titled \'Addressing sustainable energy intermittence for green ammonia production\' from the year 2023 was cited 4 times.\nThe paper titled \'Extension of Geldart classification based on the magnitude of interparticle forces\' from the year 2023 was cited 0 times.\nThe paper titled \'Reaction mechanism of thermal decomposition of Phosphogypsum\' from the year 2023 was cited 0 times.\nThe paper titled \'An improved position reconstruction method for radioactive particle tracking\' from the year 2023 was cited 0 times.\nThe paper titled \'Quantification of interparticle forces in gas-agglomerated particles fluidized beds\' from the year 2023 was cited 1 times.\nThe paper titled \'High quality products from microwave catalytic pyrolysis of heavy oil and polyethylene\' from the year 2023 was cited 0 times.\nThe paper titled \'Temperature Distribution Assessment in Gas-Solid Reactive and Nonreactive Systems Heated by Microwaves\' from the year 2023 was cited 2 times.\nThe paper titled \'Microwave-Assisted Nickel and Vanadium Removal from Crude Petroleum Oil Using Bis(2-ethylhexyl)phosphoric Acid: A Kinetic Study\' from the year 2023 was cited 0 times.\nThe paper titled \'Reduced Graphene Oxide/Barium Ferrite Ceramic Nanocomposite Synergism for High EMI Wave Absorption\' from the year 2023 was cited 0 times.\nThe paper titled \'Gas jet penetration in gas-solid fluidized and jetting-fluidized beds - A review\' from the year 2023 was cited 1 times.\nThe paper titled \'On geometry of multiscale mass action law and its fluctuations\' from the year 2023 was cited 0 times.\nThe paper titled \'A modelling approach to investigate the performance of slurry bubble column reactors implementing Fischer–Tropsch synthesis\' from the year 2023 was cited 0 times.\nThe paper titled \'Characterization and Modeling of a Microwave Reactor for the Open-Loop Control of its Impedance\' from the year 2023 was cited 0 times.\nThe paper titled \'Thrust characteristics of nano-carbon/Al/oxygenated salt nanothermites for micro-energetic applications\' from the year 2023 was cited 0 times.\nThe paper titled \'Comparative life cycle assessment of conventional and novel microalgae production systems and environmental impact mitigation in urban-industrial symbiosis\' from the year 2023 was cited 4 times.\nThe paper titled \'A correlation for average droplet diameter in rotating packed beds\' from the year 2023 was cited 1 times.\nThe paper titled \'Effects of solid particles on bubble breakup and coalescence in slurry bubble columns\' from the year 2022 was cited 2 times.\nThe paper titled \'Process development and techno-economic analysis of microwave-assisted demetallization and desulfurization of crude petroleum oil\' from the year 2022 was cited 5 times.\nThe paper titled \'Experimental methods in chemical engineering: Optical fibre probes in multiphase systems\' from the year 2022 was cited 1 times.\nThe paper titled \'Combustion behaviour and reaction kinetics of GO/Al/oxidizing salts ternary nanothermites\' from the year 2022 was cited 2 times.\nThe paper titled \'Microwave-responsive SiC foam@zeolite core-shell structured catalyst for catalytic pyrolysis of plastics\' from the year 2022 was cited 19 times.\nThe paper titled \'Superior quality chemically reduced graphene oxide for high performance EMI shielding materials\' from the year 2022 was cited 4 times.\nThe paper titled \'Microwave-assisted catalytic pyrolysis of paraffin wax\' from the year 2022 was cited 7 times.\nThe paper titled \'Two-Phase flow characterization of a rotating packed bed through CFD simulation in OpenFOAM\' from the year 2022 was cited 5 times.\nThe paper titled \'Effect of particle angularity on flow regime transitions and segregation of bidisperse blends in a rotating drum\' from the year 2022 was cited 4 times.\nThe paper titled \'Preface: Special issue of "multiphase Flows in Process Engineering: Recent Experimental, Theoretical and Numerical Developments"\' from t ...

# %%
def count_tokens(text):
    return len(text.split())

#text = "This is a sample sentence to calculate the number of tokens."
print(count_tokens(text))
# Out:
# 7870

# %%
#pip install spacy
#!python -m spacy download en_core_web_sm

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def count_tokens(text):
    doc = nlp(text)
    return len([token.text for token in doc])

#textt = "OpenAI's large language models (sometimes referred to as GPT's) process text using tokens, which are common sequences of characters found in a set of text. The models learn to understand the statistical relationships between these tokens, and excel at producing the next token in a sequence of tokens.You can use the tool below to understand how a piece of text might be tokenized by a language model, and the total count of tokens in that piece of text.It's important to note that the exact tokenization process varies between models. Newer models like GPT-3.5 and GPT-4 use a different tokenizer than our legacy GPT-3 and Codex models, and will produce different tokens for the same input text."
print(count_tokens(text))
# Out:
# 10009

# %%
from transformers import GPT2Tokenizer
# Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# Tokenize the text and count the number of tokens
tokens = tokenizer.encode(text, return_tensors='pt')
num_tokens = len(tokens[0])
print(f"Number of tokens: {num_tokens}")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (11818 > 1024). Running this sequence through the model will result in indexing errors
# Number of tokens: 11818

# %% [markdown]
# Variable *publications* is a list of papers, where for every paper corresponding dictionary contains publiaction year ('year'),
# number of citation ('cited'), scopus ID of this document ('scopusid'), title ('title') and journal where the paper was published ('journal')

# %%
for publ in publications:
    print('')
    print(publ['year'], publ['title'])
    print( 'cited ', publ['cited'], 'times',  ' scopus ID:', publ['scopusid'])
    print('published in:', publ['journal'])
# Out:
# 2023 Machine Learning Based Recommender Systems for Crop Selection: A Systematic Literature Review
# cited  0 times  scopus ID: 85168996421
# published in: Studies in Computational Intelligence
#
# 2022 A Systematic National Stocktake of Crop Models in Morocco
# cited  7 times  scopus ID: 85131224557
# published in: Ecological Modelling
#
# 2021 A review of center of pressure (COP) variables to quantify standing balance in elderly people: Algorithms and open-access code*
# cited  53 times  scopus ID: 85119482532
# published in: Physiological Reports
#
# 2019 New security architecture using hybrid IDS for virtual private clouds
# cited  2 times  scopus ID: 85078316999
# published in: 2019 3rd International Conference on Intelligent Computing in Data Sciences, ICDS 2019
#
# 2015 A proposal for improving spoken dialog systems using context information fusion
# cited  0 times  scopus ID: 84960533080
# published in: 2015 18th International Conference on Information Fusion, Fusion 2015
#
# 2015 Modeling human-machine interaction by means of a sample selection method
# cited  1 times  scopus ID: 84931040355
# published in: Communications in Computer and Information Science
#
# 2014 Sample selection based active learning for imbalanced data
# cited  8 times  scopus ID: 84928537015
# published in: Proceedings - 10th International Conference on Signal-Image Technology and Internet-Based Systems, SITIS 2014
#
# 2013 Prediction of firm's financial crash-evidence from the factor analysis model
# cited  0 times  scopus ID: 84887905557
# published in: Intelligent Systems and Decision Making for Risk Analysis and Crisis Response - Proceedings of the 4th International Conference on Risk Analysis and Crisis Response, RACR 2013
#
# 2012 Intrusion Detection based Sample Selection for imbalanced data distribution
# cited  12 times  scopus ID: 84874501996
# published in: 2nd International Conference on Innovative Computing Technology, INTECH 2012
#
# 2012 Learning from imbalanced data using methods of sample selection
# cited  3 times  scopus ID: 84869850124
# published in: Proceedings of 2012 International Conference on Multimedia Computing and Systems, ICMCS 2012

# %% [markdown]
# If you need more detailes about a publication *full_result* conatains more information

# %%
len(full_result), type(full_result)
# Out:
# (10, list)

# %%
#full_result

# %%
full_result[0].keys()
# Out:
# dict_keys(['@_fa', 'link', 'prism:url', 'dc:identifier', 'eid', 'dc:title', 'dc:creator', 'prism:publicationName', 'prism:issn', 'prism:eIssn', 'prism:volume', 'prism:pageRange', 'prism:coverDate', 'prism:coverDisplayDate', 'prism:doi', 'citedby-count', 'affiliation', 'prism:aggregationType', 'subtype', 'subtypeDescription', 'source-id', 'openaccess', 'openaccessFlag', 'freetoread', 'freetoreadLabel'])

# %% [markdown]
# #### For every publucation full_result list contains things like issn, doi, type of the journal, etc.
# #### See full output for one of the publicaitons below

# %%
#full_result[0]

# %% [markdown]
# ### 7. Obtain detailed information about a given publication using Scopus ID

# %%
publication_scopus_id = '85168806520'
scp_doc = AbsDoc(scp_id = publication_scopus_id)
if scp_doc.read(client):
    print("Publication record obtained successfully")
    result = scp_doc.data
else:
    print("Something went wrong ... ")
    result = ''
# Out:
# Publication record obtained successfully

# %% [markdown]
# #### result contains a lot of information about the paper, author list and their affiliations, abstract of the publication, reference list, etc.
# below is the abstract of the given paper

# %%
scp_doc.data['item']['bibrecord']['head']['abstracts']#reference (['head', 'item-info', 'tail'])
# Out:
# '© 2023 by the authors.Accurate and spatially distributed precipitation data are fundamental to effective water resource management. In Morocco, as in other arid and semi-arid regions, precipitation exhibits significant spatial and temporal variability. Indeed, there is an intra- and inter-annual variability and the northwest is rainier than the rest of the country. In the Bouregreg watershed, this irregularity, along with a sparse gauge network, poses a major challenge for water resource management. In this context, remote sensing data could provide a viable alternative. This study aims precisely to evaluate the performance of four gridded daily precipitation products: three IMERG-V06 datasets (GPM-F, GPM-L, and GPM-E) and a reanalysis product (ERA5). The evaluation is conducted using 11 rain gauge stations over a 20-year period (2000–2020) on various temporal scales (daily, monthly, seasonal, and annual) using a pixel-to-point approach, employing different classification and regression metrics of machine learning. According to the findings, the GPM products showed high accuracy with a low margin of error in terms of bias, RMSE, and MAE. However, it was observed that ERA5 outperformed the GPM products in identifying spatial precipitation patterns and demonstrated a stronger correlation. The evaluation results also showed that the gridded precipitation products performed better during the summer months for seasonal assessment, with relatively lower accuracy and higher biases during rainy months. Furthermore, these gridded products showed excellent performance in capturing different precipitation intensities, with the highest accuracy observed for light rain. This is particularly important for arid and semi-arid regions where most precipitation falls under the low-intensity category. Although gridded precipitation estimates provide global coverage at high spatiotemporal resolutions, their accuracy is currently insufficient and would require improvement. To address this, we employed an artificial neural network (ANN) model for bias correction and enhancing raw precipitation estimates from the GPM-F product. The results indicated a slight increase in the correlation coefficient and a significant reduction in biases, RMSE, and MAE. Consequently, this research currently supports the applicability of GPM-F data in North Western Morocco.'

# %%
# Parse the JSON data
data = scp_doc.data

# Extract the authors' names
authors = []
author_groups = data["item"]["bibrecord"]["head"]["author-group"]
for author_group in author_groups:
    print(author_group)
    for author in author_group["author"]:
        full_name = f"{author['ce:given-name']} {author['ce:surname']}"
        authors.append(full_name)

# Extract the abstract
abstract = data["item"]["bibrecord"]["head"]["abstracts"]

# Print the authors' names and the abstract
print("Authors:", authors)
print("\nAbstract:", abstract)
# Out:
# affiliation
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [244], in <cell line: 7>()
#       7 for author_group in author_groups:
#       8     print(author_group)
# ----> 9     for author in author_group["author"]:
#      10         full_name = f"{author['ce:given-name']} {author['ce:surname']}"
#      11         authors.append(full_name)
#
# TypeError: string indices must be integers

# %%
#author_groups

# %%
# Extract the authors' information including name, organization, and affiliation
authors_info = []
author_groups = data["item"]["bibrecord"]["head"]["author-group"]
for author_group in author_groups:
    for author in author_group["author"]:
        full_name = f"{author['ce:given-name']} {author['ce:surname']}"
        organizations = [org["$"] for org in author_group["affiliation"]["organization"]]
        authors_info.append({
            "name": full_name,
            "organizations": organizations
        })

# Extract the abstract
abstract = data["item"]["bibrecord"]["head"]["abstracts"]

# Print the authors' names, organizations, and the abstract
for author_info in authors_info:
    print("Author:", author_info["name"])
    print("Organizations:", ", ".join(author_info["organizations"]))
print("\nAbstract:", abstract)
# Out:
# Author: Oumnia Ennaji
# Organizations: Chair of Soil Science, University Mohammed VI Polytechnic
# Author: Leonardus Vergütz
# Organizations: Chair of Soil Science, University Mohammed VI Polytechnic
# Author: Oumnia Ennaji
# Organizations: African Genome Center, University Mohammed VI Polytechnic
# Author: Achraf El Allali
# Organizations: African Genome Center, University Mohammed VI Polytechnic
#
# Abstract: © 2023 The AuthorsIn agriculture, precise fertilization and effective nutrient management are critical. Machine learning (ML) has recently been increasingly used to develop decision support tools for modern agricultural systems, including nutrient management, to improve yields while reducing expenses and environmental impact. ML based systems require huge amounts of data from different platforms to handle non-linear tasks and build predictive models that can improve agricultural productivity. This study reviews machine learning based techniques for estimating fertilizer and nutrient status that have been developed in the last decade. A thorough investigation of detection and classification approaches was conducted, which served as the basis for a detailed assessment of the key challenges that remain to be addressed. The research findings suggest that rapid improvements in machine learning and sensor technology can provide cost-effective and thorough nutrient assessment and decision-making solutions. Future research directions are also recommended to improve the practical application of this technology.

# %%
import pandas as pd

# Extract the authors' information including name, organization, and affiliation
authors_info = []
author_groups = data["item"]["bibrecord"]["head"]["author-group"]
for author_group in author_groups:
    for author in author_group["author"]:
        full_name = f"{author['ce:given-name']} {author['ce:surname']}"
        organizations = [org["$"] for org in author_group.get("affiliation", {}).get("organization", [])]  # Handling potential absence of affiliation or organization key
        authors_info.append({
            "name": full_name,
            "organizations": ", ".join(organizations)  # Join organizations with commas
        })

# Create a DataFrame from the authors_info list of dictionaries
df = pd.DataFrame(authors_info)

# Save the DataFrame to a CSV file
#df.to_csv('authors_info.csv', index=False)

# Extract the abstract
abstract = data["item"]["bibrecord"]["head"]["abstracts"]

# Print the authors' names, organizations, and the abstract
for index, author_info in df.iterrows():
    print("Author:", author_info["name"])
    print("Organizations:", author_info["organizations"])
print("\nAbstract:", abstract)
# Out:
#                 name                                      organizations
# 0      Oumnia Ennaji  Chair of Soil Science, University Mohammed VI ...
# 1  Leonardus Vergütz  Chair of Soil Science, University Mohammed VI ...
# 2      Oumnia Ennaji  African Genome Center, University Mohammed VI ...
# 3   Achraf El Allali  African Genome Center, University Mohammed VI ...

# %%
#scp_doc.data['item']['bibrecord']['head']['author-group']

# %% [markdown]
# #### Save information about this publication to json file *publication_record.json*

# %%
with open('publication_record.json', 'w') as fp:
    json.dump(result, fp, indent=4)

# %%
#####################################

# %%
author_scopus_id = '38861057100'
publications, full_result = author_pubs(author_scopus_id, client)
dff = pd.DataFrame(publications)
dff
# Out:
#     year cited     scopusid  \
# 0   2024     1  85196673994
# 1   2024     1  85194922437
# 2   2024     0  85192324913
# 3   2024     0  85196042809
# 4   2024     1  85189301682
# ..   ...   ...          ...
# 57  2012    26  84858674150
# 58  2011    16  80052648526
# 59  2011    28  84876434387
# 60  2011    55  79960757384
# 61  2011    24  79960103335
#
#                                                 title  \
# 0   Species interactions and bacterial inoculation...
# 1   Drought-tolerant rhizobacteria with predicted ...
# 2   Use of organo-mineral amendments and Lupinus a...
# 3   Multifunctional agricultural inputs based on b...
# 4   Phosphate bio-solubilization and cadmium toler...
# ..                                                ...
# 57  Identification at the species and symbiovar le...
# 58  Nodule phosphorus requirement and O <inf>2</in...
# 59  Effect of salinity on nodulation, nitrogen fix...
# 60  Agro-physiological responses of Moroccan alfal...
# 61  The nodule conductance to O<inf>2</inf> diffus...
#
#                                              jrnlname
# 0               Environmental and Experimental Botany
# 1                            Microbiological Research
# 2               Environmental and Experimental Botany
# 3                                      Algal Research
# 4               Environmental and Experimental Botany
# ..                                                ...
# 57                Systematic and Applied Microbiology
# 58  Acta Agriculturae Scandinavica Section B: Soil...
# 59                                          Symbiosis
# 60                        Seed Science and Technology
# 61                                          Symbiosis
#
# [62 rows x 5 columns]

# %%
dff.to_csv('Bargaz, Adnane.csv',index = False )

# %%
def get_authors_and_abstracts(scopusid):
    scp_doc = AbsDoc(scp_id = scopusid)
    if scp_doc.read(client):
        result = scp_doc.data
        # Extracting authors
        #authors_info = []
        #author_groups = result["item"]["bibrecord"]["head"]["author-group"]
        #for author_group in author_groups:
           # for author in author_group["author"]:
             #   full_name = f"{author['ce:given-name']} {author['ce:surname']}"
              #  authors_info.append(full_name)
        #authors = ', '.join(authors_info)
        # Extracting abstracts
        abstracts = result["item"]["bibrecord"]["head"]["abstracts"]
        return pd.Series([abstracts], index=['Abstracts'])
    else:
        return pd.Series([None, None], index=['Abstracts'])

# Applying the function to each row of the dataframe
dff[['Abstracts']] = dff['scopusid'].apply(lambda x: get_authors_and_abstracts(x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [30], in <cell line: 20>()
#      17         return pd.Series([None, None], index=['Abstracts'])
#      19 # Applying the function to each row of the dataframe
# ---> 20 dff[['Abstracts']] = dff['scopusid'].apply(lambda x: get_authors_and_abstracts(x))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# Input In [30], in <lambda>(x)
#      17         return pd.Series([None, None], index=['Abstracts'])
#      19 # Applying the function to each row of the dataframe
# ---> 20 dff[['Abstracts']] = dff['scopusid'].apply(lambda x: get_authors_and_abstracts(x))
#
# Input In [30], in get_authors_and_abstracts(scopusid)
#       1 def get_authors_and_abstracts(scopusid):
#       2     scp_doc = AbsDoc(scp_id = scopusid)
# ----> 3     if scp_doc.read(client):
#       4         result = scp_doc.data
#       5         # Extracting authors
#       6         #authors_info = []
#       7         #author_groups = result["item"]["bibrecord"]["head"]["author-group"]
#    (...)
#      12         #authors = ', '.join(authors_info)
#      13         # Extracting abstracts
#
# File ~\AppData\Roaming\Python\Python38\site-packages\elsapy\elsdoc.py:85, in AbsDoc.read(self, els_client)
#      82 def read(self, els_client = None):
#      83     """Reads the JSON representation of the document from ELSAPI.
#      84          Returns True if successful; else, False."""
# ---> 85     if super().read(self.__payload_type, els_client):
#      86         return True
#      87     else:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\elsapy\elsentity.py:71, in ElsEntity.read(self, payloadType, elsClient)
#      69     raise ValueError('''Entity object not currently bound to elsClient instance. Call .read() with elsClient argument or set .client attribute.''')
#      70 try:
# ---> 71     api_response = self.client.exec_request(self.uri)
#      72     if isinstance(api_response[payloadType], list):
#      73         self._data = api_response[payloadType][0]
#
# File ~\AppData\Roaming\Python\Python38\site-packages\elsapy\elsclient.py:110, in ElsClient.exec_request(self, URL)
#     108     headers["X-ELS-Insttoken"] = self.inst_token
#     109 logger.info('Sending GET request to ' + URL)
# --> 110 r = requests.get(
#     111     URL,
#     112     headers = headers
#     113     )
#     114 self.__ts_last_req = time.time()
#     115 self._status_code=r.status_code
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File C:\ProgramData\Anaconda3\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File C:\ProgramData\Anaconda3\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File C:\ProgramData\Anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
dff

# %%
# Transform the DataFrame to text
text_list = dff.apply(lambda row: f"The paper titled '{row['title']}' from the year {row['year']} was cited {row['cited']} times.", axis=1).tolist()
text = "\n".join(text_list)
text

# %%
#for t in dff['scopusid'].head(5):
scp_doc = AbsDoc(scp_id = '85163336572')
result = scp_doc.data
scp_doc

# %%
scp_doc = AbsDoc(scp_id = '85171596509')
if scp_doc.read(client):
    print("Publication record obtained successfully")
    result = scp_doc.data
else:
    print("Something went wrong ... ")
    result = ''
# Out:
# Publication record obtained successfully

# %%
article_title = result["item"]["bibrecord"]["head"]["citation-title"]
article_title
# Out:
# 'Energy efficiency and hygrothermal performance of hemp clay walls for Moroccan residential buildings: An integrated lab-scale, in-situ and simulation-based assessment'

# %%
#result

# %%
with open('result.json', 'w') as file:
    json.dump(data, file, indent=4, sort_keys=True)

# %%
dz = pd.DataFrame()
for t in dff['scopusid']:
    scp_doc = AbsDoc(scp_id = t)
    if scp_doc.read(client):
        result = scp_doc.data
    else:
        print("Something went wrong ... ")
    #data = scp_doc.data
    print(t)
    #print(result)
    # Extract the article title
    article_title = result["item"]["bibrecord"]["head"]["citation-title"]

    # Extract authors' information including name and affiliation
    authors_info = []
    author_groups = result["item"]["bibrecord"]["head"]["author-group"]
    for author_group in author_groups:
        for author in author_group["author"]:
            full_name = f"{author['ce:given-name']} {author['ce:surname']}"
            #organizations = [org["$"] for org in author_group["affiliation"]["organization"]]
            authors_info.append({
                "Author": full_name
               # "Affiliation": ", ".join(organizations)
            })
    # Create a DataFrame
    df = pd.DataFrame(authors_info)

    # Add Scopus ID and Article Title columns
    #df["ScopusID"] = "your_scopus_id_here"  # Replace with the actual Scopus ID
    df["Article Title"] = article_title

    # Reorder columns
    df = df[[ "Article Title", "Author"]]
    # Print the DataFrame
    df = df.groupby('Article Title').agg({
        'Author': ', '.join
    }).reset_index()
    df['scopusid'] = t
    df['abstracts'] = result["item"]["bibrecord"]["head"]["abstracts"]
    # Concatenate the dataframes vertically (along rows)
    dz = pd.concat([df,dz])
    # Reset the index of the concatenated dataframe
    dz.reset_index(drop=True, inplace=True)
dz
# Out:
# 85163336572
# 85161355854
# 85149836777
# 85164146999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [319], in <cell line: 2>()
#       2 for t in dff['scopusid']:
#       3     scp_doc = AbsDoc(scp_id = t)
# ----> 4     if scp_doc.read(client):
#       5         result = scp_doc.data
#       6     else:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\elsapy\elsdoc.py:85, in AbsDoc.read(self, els_client)
#      82 def read(self, els_client = None):
#      83     """Reads the JSON representation of the document from ELSAPI.
#      84          Returns True if successful; else, False."""
# ---> 85     if super().read(self.__payload_type, els_client):
#      86         return True
#      87     else:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\elsapy\elsentity.py:71, in ElsEntity.read(self, payloadType, elsClient)
#      69     raise ValueError('''Entity object not currently bound to elsClient instance. Call .read() with elsClient argument or set .client attribute.''')
#      70 try:
# ---> 71     api_response = self.client.exec_request(self.uri)
#      72     if isinstance(api_response[payloadType], list):
#      73         self._data = api_response[payloadType][0]
#
# File ~\AppData\Roaming\Python\Python38\site-packages\elsapy\elsclient.py:99, in ElsClient.exec_request(self, URL)
#      97 interval = time.time() - self.__ts_last_req
#      98 if (interval < self.__min_req_interval):
# ---> 99     time.sleep( self.__min_req_interval - interval )
#     101 ## Construct and execute request
#     102 headers = {
#     103     "X-ELS-APIKey"  : self.api_key,
#     104     "User-Agent"    : self.__user_agent,
#     105     "Accept"        : 'application/json'
#     106     }
#
# KeyboardInterrupt:

# %%
#dz['abstracts']

# %%
# Extract the article title
article_title = data["item"]["bibrecord"]["head"]["citation-title"]

# Extract authors' information including name and affiliation
authors_info = []
author_groups = data["item"]["bibrecord"]["head"]["author-group"]
for author_group in author_groups:
    for author in author_group["author"]:
        full_name = f"{author['ce:given-name']} {author['ce:surname']}"
        #organizations = [org["$"] for org in author_group["affiliation"]["organization"]]
        authors_info.append({
            "Author": full_name
           # "Affiliation": ", ".join(organizations)
        })
# Create a DataFrame
df = pd.DataFrame(authors_info)

# Add Scopus ID and Article Title columns
#df["ScopusID"] = "your_scopus_id_here"  # Replace with the actual Scopus ID
df["Article Title"] = article_title

# Reorder columns
df = df[[ "Article Title", "Author"]]
# Print the DataFrame
df = df.groupby('Article Title').agg({
    'Author': ', '.join
}).reset_index()
df['scopusid'] = t
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [328], in <cell line: 2>()
#       1 # Extract the article title
# ----> 2 article_title = data["item"]["bibrecord"]["head"]["citation-title"]
#       4 # Extract authors' information including name and affiliation
#       5 authors_info = []
#
# TypeError: list indices must be integers or slices, not str

# %%
import requests
import json


def fetch_scopus_data(start=0, count=25):
    base_url = "https://api.elsevier.com/content/search/scopus"
    
    headers = {
        "Accept": "application/json",
        "X-ELS-APIKey": '7762f59ce3b9cb9117c74958bab4202b'
    }
    
    params = {
        "query": "AFFIL(um6p)",
        "start": start,
        "count": count
    }
    
    response = requests.get(base_url, headers=headers, params=params)
    
    return response.json()

# total number of documents to fetch
total_documents = 200
count_per_request = 25  # you can adjust this number based on your preference or Scopus API limits


dz = pd.DataFrame(authors_info)
for start in range(0, total_documents, count_per_request):
    data = fetch_scopus_data(start=start, count=count_per_request)
    #print(json.dumps(data, indent=2))  # Pretty print the JSON data, or you can process/save data as needed
    # Assuming json_data contains your JSON object
    json_data = data

    entries = json_data['search-results']['entry']

    # Extracting the information
   
    data = []
    for entry in entries:
        title = entry.get('dc:title')
        authors = entry.get('dc:creator')
        source = entry.get('prism:publicationName')
        year = entry.get('prism:coverDate')
        citations = entry.get('citedby-count')
        Source_type = entry.get('subtypeDescription')
        openaccess = entry.get('openaccess')
        SCOPUS_ID = entry.get('dc:identifier')

        data.append([title, authors, source, year, citations,Source_type,openaccess,SCOPUS_ID])

    # Creating a pandas DataFrame
    columns = ['Document title', 'Authors', 'Source', 'Year', 'Citations','Source_type','openaccess','SCOPUS_ID']
    df = pd.DataFrame(data, columns=columns)
    dz = pd.concat([df,dz])
    # Reset the index of the concatenated dataframe
    dz.reset_index(drop=True, inplace=True)
    # Now, df contains the extracted data as a pandas DataFrame
dz['SCOPUS_ID'] = dz['SCOPUS_ID'].str.replace('SCOPUS_ID:', '', regex=False)
dz
# Out:
#                                         Document title         Authors  \
# 0    Comparison of Phenol Adsorption Property and M...      Dehmani Y.
# 1    Assessment of GPM Satellite Precipitation Perf...    Benkirane M.
# 2    Large Field Screening for Resistance to Broomr...     En-nahli Y.
# 3    First Report of the Branched Broomrape (Phelip...      El Amri M.
# 4    PCA-based detection of phosphorous deficiency ...  El-Mejjaouy Y.
# ..                                                 ...             ...
# 202                                                NaN             NaN
# 203                                                NaN             NaN
# 204                                                NaN             NaN
# 205                                                NaN             NaN
# 206                                                NaN             NaN
#
#                   Source        Year Citations Source_type openaccess  \
# 0    Water (Switzerland)  2023-05-01         4     Article          1
# 1             Atmosphere  2023-05-01         1     Article          1
# 2                 Plants  2023-05-01         0     Article          1
# 3          Horticulturae  2023-05-01         0     Article          1
# 4               PLoS ONE  2023-05-01         0     Article          1
# ..                   ...         ...       ...         ...        ...
# 202                  NaN         NaN       NaN         NaN        NaN
# 203                  NaN         NaN       NaN         NaN        NaN
# 204                  NaN         NaN       NaN         NaN        NaN
# 205                  NaN         NaN       NaN         NaN        NaN
# 206                  NaN         NaN       NaN         NaN        NaN
#
#        SCOPUS_ID                          Author
# 0    85160597789                             NaN
# 1    85160587631                             NaN
# 2    85160574283                             NaN
# 3    85160250452                             NaN
# 4    85160157715                             NaN
# ..           ...                             ...
# 202          NaN  Cristian Mauricio Vega Cuichán
# 203          NaN             Ésio de Castro Paes
# 204          NaN               Cleberson Ribeiro
# 205          NaN               Leonardus Vergütz
# 206          NaN           Roberto Fontes Araujo
#
# [207 rows x 9 columns]

# %%
dz.to_csv('all_the data.csv')

# %%
import requests
import json

def fetch_scopus_data(start=0, count=25):
    base_url = "https://api.elsevier.com/content/search/scopus"
    
    headers = {
        "Accept": "application/json",
        "X-ELS-APIKey": '7762f59ce3b9cb9117c74958bab4202b'  # Make sure api_key is defined
    }
    
    params = {
        "query": "AFFIL(um6p)",
        "start": start,
        "count": count
    }
    
    response = requests.get(base_url, headers=headers, params=params)
    
    return response.json()


# total number of documents to fetch
total_documents = 200
count_per_request = 25  # you can adjust this number based on your preference or Scopus API limits

# List to accumulate data
all_data = []

for start in range(0, total_documents, count_per_request):
    data = fetch_scopus_data(start=start, count=count_per_request)
    all_data.append(data)  # Add fetched data to the list

# Save all data to a JSON file
#with open('scopus_data.json', 'w') as file:
   # json.dump(all_data, file, indent=2)

# %%
all_data
# Out:
# [{'search-results': {'opensearch:totalResults': '1371',
#    'opensearch:startIndex': '0',
#    'opensearch:itemsPerPage': '25',
#    'opensearch:Query': {'@role': 'request',
#     '@searchTerms': 'AFFIL(um6p)',
#     '@startPage': '0'},
#    'link': [{'@_fa': 'true',
#      '@ref': 'self',
#      '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=AFFIL%28um6p%29',
#      '@type': 'application/json'},
#     {'@_fa': 'true',
#      '@ref': 'first',
#      '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=AFFIL%28um6p%29',
#      '@type': 'application/json'},
#     {'@_fa': 'true',
#      '@ref': 'next',
#      '@href': 'https://api.elsevier.com/content/search/scopus?start=25&count=25&query=AFFIL%28um6p%29',
#      '@type': 'application/json'},
#     {'@_fa': 'true',
#      '@ref': 'last',
#      '@href': 'https://api.elsevier.com/content/search/scopus?start=1346&count=25&query=AFFIL%28um6p%29',
#      '@type': 'application/json'}],
#    'entry': [{'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173505139'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173505139?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173505139&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173505139&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S1010603023006767'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85173505139',
#      'dc:identifier': 'SCOPUS_ID:85173505139',
#      'eid': '2-s2.0-85173505139',
#      'dc:title': 'Investigating the long-term stability of photoluminescence lifetimes in PMMA films doped with β-diketonate europium complexes based on bipyridine and terpyridine derivatives',
#      'dc:creator': 'Essahili O.',
#      'prism:publicationName': 'Journal of Photochemistry and Photobiology A: Chemistry',
#      'prism:issn': '10106030',
#      'prism:volume': '447',
#      'prism:pageRange': None,
#      'prism:coverDate': '2024-01-15',
#      'prism:coverDisplayDate': '15 January 2024',
#      'prism:doi': '10.1016/j.jphotochem.2023.115211',
#      'pii': 'S1010603023006767',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '115211',
#      'source-id': '26966',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85174436716'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85174436716?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85174436716&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85174436716&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85174436716',
#      'dc:identifier': 'SCOPUS_ID:85174436716',
#      'eid': '2-s2.0-85174436716',
#      'dc:title': 'Comparison of Optimal Sensor Placement Technics for Structural Health Monitoring Application',
#      'dc:creator': 'Mghazli M.O.',
#      'prism:publicationName': 'Lecture Notes in Civil Engineering',
#      'prism:issn': '23662557',
#      'prism:eIssn': '23662565',
#      'prism:isbn': [{'@_fa': 'true', '$': '9789819940486'}],
#      'prism:volume': '369',
#      'prism:pageRange': '481-491',
#      'prism:coverDate': '2024-01-01',
#      'prism:coverDisplayDate': '2024',
#      'prism:doi': '10.1007/978-981-99-4049-3_38',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Green Energy Park',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Laboratoire de Tribologie et Dynamique des Systèmes',
#        'affiliation-city': 'Ecully',
#        'affiliation-country': 'France'},
#       {'@_fa': 'true',
#        'affilname': "Ecole Mohammadia d'Ingenieurs, Mohammed V University in Rabat",
#        'affiliation-city': 'Rabat',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Book Series',
#      'subtype': 'cp',
#      'subtypeDescription': 'Conference Paper',
#      'source-id': '21100889404',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173440380'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173440380?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173440380&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173440380&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S1570870523002251'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85173440380',
#      'dc:identifier': 'SCOPUS_ID:85173440380',
#      'eid': '2-s2.0-85173440380',
#      'dc:title': 'Multi-Agent Deep Reinforcement Learning for content caching within the Internet of Vehicles',
#      'dc:creator': 'Knari A.',
#      'prism:publicationName': 'Ad Hoc Networks',
#      'prism:issn': '15708705',
#      'prism:volume': '152',
#      'prism:pageRange': None,
#      'prism:coverDate': '2024-01-01',
#      'prism:coverDisplayDate': '1 January 2024',
#      'prism:doi': '10.1016/j.adhoc.2023.103305',
#      'pii': 'S1570870523002251',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '103305',
#      'source-id': '26799',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173421198'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173421198?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173421198&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173421198&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0883902623000733'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85173421198',
#      'dc:identifier': 'SCOPUS_ID:85173421198',
#      'eid': '2-s2.0-85173421198',
#      'dc:title': 'Climate impact, institutional context, and national climate change adaptation IP protection rates',
#      'dc:creator': 'Yoon H.',
#      'prism:publicationName': 'Journal of Business Venturing',
#      'prism:issn': '08839026',
#      'prism:volume': '39',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2024-01-01',
#      'prism:coverDisplayDate': 'January 2024',
#      'prism:doi': '10.1016/j.jbusvent.2023.106359',
#      'pii': 'S0883902623000733',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Leeds University Business School',
#        'affiliation-city': 'Leeds',
#        'affiliation-country': 'United Kingdom'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '106359',
#      'source-id': '23860',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherhybridgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#        {'$': 'Hybrid Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85172417610'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85172417610?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85172417610&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85172417610&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85172417610',
#      'dc:identifier': 'SCOPUS_ID:85172417610',
#      'eid': '2-s2.0-85172417610',
#      'dc:title': 'Effect of Bilayer Variation on the Properties of CrN/CrAlN Multilayer Coatings Produced by DC Magnetron Sputtering',
#      'dc:creator': 'Aouadi K.',
#      'prism:publicationName': 'Mechanisms and Machine Science',
#      'prism:issn': '22110984',
#      'prism:eIssn': '22110992',
#      'prism:isbn': [{'@_fa': 'true', '$': '9783031426582'}],
#      'prism:volume': '144',
#      'prism:pageRange': '161-168',
#      'prism:coverDate': '2024-01-01',
#      'prism:coverDisplayDate': '2024',
#      'prism:doi': '10.1007/978-3-031-42659-9_18',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'University of Carthage, Ecole Polytechnique de Tunisie',
#        'affiliation-city': 'La Marsa',
#        'affiliation-country': 'Tunisia'}],
#      'prism:aggregationType': 'Book Series',
#      'subtype': 'cp',
#      'subtypeDescription': 'Conference Paper',
#      'source-id': '21100298603',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171596509'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171596509?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85171596509&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85171596509&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0306261923013314'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85171596509',
#      'dc:identifier': 'SCOPUS_ID:85171596509',
#      'eid': '2-s2.0-85171596509',
#      'dc:title': 'Energy efficiency and hygrothermal performance of hemp clay walls for Moroccan residential buildings: An integrated lab-scale, in-situ and simulation-based assessment',
#      'dc:creator': 'Es-sakali N.',
#      'prism:publicationName': 'Applied Energy',
#      'prism:issn': '03062619',
#      'prism:volume': '352',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-15',
#      'prism:coverDisplayDate': '15 December 2023',
#      'prism:doi': '10.1016/j.apenergy.2023.121967',
#      'pii': 'S0306261923013314',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Green Energy Park',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Rabat National School of Mines',
#        'affiliation-city': 'Rabat',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '121967',
#      'source-id': '28801',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85168412856'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85168412856?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168412856&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85168412856&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0048969723049215'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85168412856',
#      'dc:identifier': 'SCOPUS_ID:85168412856',
#      'eid': '2-s2.0-85168412856',
#      'dc:title': 'Effect of alkaline leaching of phosphogypsum on sulfate reduction activity and bacterial community composition using different sources of anaerobic microbial inoculum',
#      'dc:creator': 'Bounaga A.',
#      'prism:publicationName': 'Science of the Total Environment',
#      'prism:issn': '00489697',
#      'prism:eIssn': '18791026',
#      'prism:volume': '904',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-15',
#      'prism:coverDisplayDate': '15 December 2023',
#      'prism:doi': '10.1016/j.scitotenv.2023.166296',
#      'pii': 'S0048969723049215',
#      'citedby-count': '1',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'}],
#      'pubmed-id': '37591387',
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '166296',
#      'source-id': '25349',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85174832818'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85174832818?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85174832818&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85174832818&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85174832818',
#      'dc:identifier': 'SCOPUS_ID:85174832818',
#      'eid': '2-s2.0-85174832818',
#      'dc:title': 'Chlorophyll performances as an indicator of compost quality: Effectiveness of liquid humic substances and compost tea',
#      'dc:creator': 'El Hayany B.',
#      'prism:publicationName': 'International Journal of Recycling of Organic Waste in Agriculture',
#      'prism:issn': '21953228',
#      'prism:eIssn': '22517715',
#      'prism:volume': '12',
#      'prism:issueIdentifier': '4',
#      'prism:pageRange': '683-698',
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.30486/ijrowa.2023.1962394.1499',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Faculté des Sciences Semlalia',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'source-id': '21100395913',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85174819155'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85174819155?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85174819155&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85174819155&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0264999323003802'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85174819155',
#      'dc:identifier': 'SCOPUS_ID:85174819155',
#      'eid': '2-s2.0-85174819155',
#      'dc:title': 'Impact of agricultural input subsidy policy on market participation and income distribution in Africa: A bottom-up/top-down approach',
#      'dc:creator': 'Camara A.',
#      'prism:publicationName': 'Economic Modelling',
#      'prism:issn': '02649993',
#      'prism:volume': '129',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1016/j.econmod.2023.106568',
#      'pii': 'S0264999323003802',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'United Nations Development Programme',
#        'affiliation-city': 'New York',
#        'affiliation-country': 'United States'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '106568',
#      'source-id': '28467',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85174485766'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85174485766?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85174485766&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85174485766&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85174485766',
#      'dc:identifier': 'SCOPUS_ID:85174485766',
#      'eid': '2-s2.0-85174485766',
#      'dc:title': 'XRF online analyzer for measurements of P<inf>2</inf>O<inf>5</inf> content in phosphate slurry',
#      'dc:creator': 'Ben Amar I.',
#      'prism:publicationName': 'Scientific Reports',
#      'prism:eIssn': '20452322',
#      'prism:volume': '13',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1038/s41598-023-45181-5',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': "Centre d'Optique, Photonique et Laser",
#        'affiliation-city': 'Quebec',
#        'affiliation-country': 'Canada'},
#       {'@_fa': 'true',
#        'affilname': 'Université Laval',
#        'affiliation-city': 'Quebec',
#        'affiliation-country': 'Canada'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '17925',
#      'source-id': '21100200805',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173748963'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85173748963?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85173748963&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85173748963&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85173748963',
#      'dc:identifier': 'SCOPUS_ID:85173748963',
#      'eid': '2-s2.0-85173748963',
#      'dc:title': 'An interventional clinical trial investigating the effects of Spirulina platensis on dental fluorosis and antioxidant system in lambs reared in endemic areas',
#      'dc:creator': 'Rahim A.',
#      'prism:publicationName': 'Scientific Reports',
#      'prism:eIssn': '20452322',
#      'prism:volume': '13',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1038/s41598-023-44058-x',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Université Hassan 1er',
#        'affiliation-city': 'Settat',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Institut National de la Recherche Agronomique, Morocco',
#        'affiliation-city': 'Rabat',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '16858',
#      'source-id': '21100200805',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171627921'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171627921?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85171627921&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85171627921&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0892687523003278'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85171627921',
#      'dc:identifier': 'SCOPUS_ID:85171627921',
#      'eid': '2-s2.0-85171627921',
#      'dc:title': 'Synthesis, characterization and uptake studies of diglycolamic acid and diglycolamide analogs adsorbents for extraction of rare earth elements',
#      'dc:creator': 'Bardovskyi R.',
#      'prism:publicationName': 'Minerals Engineering',
#      'prism:issn': '08926875',
#      'prism:volume': '204',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1016/j.mineng.2023.108313',
#      'pii': 'S0892687523003278',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': "Université Côte d'Azur",
#        'affiliation-city': 'Nice',
#        'affiliation-country': 'France'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '108313',
#      'source-id': '16936',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171474945'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171474945?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85171474945&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85171474945&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S089268752300376X'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85171474945',
#      'dc:identifier': 'SCOPUS_ID:85171474945',
#      'eid': '2-s2.0-85171474945',
#      'dc:title': 'Passive treatment residues of mine drainage: Mineralogical and environmental assessment, and management avenues',
#      'dc:creator': 'Mehdaoui H.Y.',
#      'prism:publicationName': 'Minerals Engineering',
#      'prism:issn': '08926875',
#      'prism:volume': '204',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1016/j.mineng.2023.108362',
#      'pii': 'S089268752300376X',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Université du Québec en Abitibi-Témiscamingue',
#        'affiliation-city': 'Rouyn-Noranda',
#        'affiliation-country': 'Canada'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 're',
#      'subtypeDescription': 'Review',
#      'article-number': '108362',
#      'source-id': '16936',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171362936'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171362936?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85171362936&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85171362936&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S2214714423008334'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85171362936',
#      'dc:identifier': 'SCOPUS_ID:85171362936',
#      'eid': '2-s2.0-85171362936',
#      'dc:title': 'Uncovering applicability of Navicula permitis algae in removing phenolic compounds: A promising solution for olive mill wastewater treatment',
#      'dc:creator': 'Elhamji S.',
#      'prism:publicationName': 'Journal of Water Process Engineering',
#      'prism:issn': '22147144',
#      'prism:volume': '56',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1016/j.jwpe.2023.104313',
#      'pii': 'S2214714423008334',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Faculté des Sciences Semlalia',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Université Cadi Ayyad',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '104313',
#      'source-id': '21100324365',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171148484'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85171148484?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85171148484&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85171148484&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85171148484',
#      'dc:identifier': 'SCOPUS_ID:85171148484',
#      'eid': '2-s2.0-85171148484',
#      'dc:title': 'Continuous treatment of highly concentrated tannery wastewater using novel porous composite beads: Central composite design optimization study',
#      'dc:creator': 'Lissaneddine A.',
#      'prism:publicationName': 'Journal of Environmental Health Science and Engineering',
#      'prism:eIssn': '2052336X',
#      'prism:volume': '21',
#      'prism:issueIdentifier': '2',
#      'prism:pageRange': '513-532',
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1007/s40201-023-00878-7',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Faculté des Sciences Semlalia',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Université Cadi Ayyad',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'source-id': '21100242835',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85170207706'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85170207706?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85170207706&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85170207706&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0169131723003137'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85170207706',
#      'dc:identifier': 'SCOPUS_ID:85170207706',
#      'eid': '2-s2.0-85170207706',
#      'dc:title': 'Design of acid-geopolymers based on clays by-products for methylene blue removal from wastewater',
#      'dc:creator': 'En-naji S.',
#      'prism:publicationName': 'Applied Clay Science',
#      'prism:issn': '01691317',
#      'prism:volume': '245',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': '1 December 2023',
#      'prism:doi': '10.1016/j.clay.2023.107126',
#      'pii': 'S0169131723003137',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Université Cadi Ayyad',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '107126',
#      'source-id': '24614',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85169762709'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85169762709?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85169762709&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85169762709&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85169762709',
#      'dc:identifier': 'SCOPUS_ID:85169762709',
#      'eid': '2-s2.0-85169762709',
#      'dc:title': 'Enabling simultaneous valorization of tannery effluent and waste plastic via sustainable preparation of Cr-BDC MOFs for water adsorption',
#      'dc:creator': 'Delhali A.',
#      'prism:publicationName': 'Scientific Reports',
#      'prism:eIssn': '20452322',
#      'prism:volume': '13',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1038/s41598-023-41840-9',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Institut des Molécules et Matériaux du Mans',
#        'affiliation-city': 'Le Mans',
#        'affiliation-country': 'France'}],
#      'pubmed-id': '37670113',
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '14653',
#      'source-id': '21100200805',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'},
#        {'$': 'publisherfullgold'},
#        {'$': 'repository'},
#        {'$': 'repositoryvor'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#        {'$': 'Gold'},
#        {'$': 'Green'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85168344982'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85168344982?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168344982&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85168344982&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85168344982',
#      'dc:identifier': 'SCOPUS_ID:85168344982',
#      'eid': '2-s2.0-85168344982',
#      'dc:title': 'Modeling genotype\xa0×\xa0environment\xa0×\xa0management interactions for a sustainable intensification under rainfed wheat cropping system in Morocco',
#      'dc:creator': 'Mamassi A.',
#      'prism:publicationName': 'Agriculture and Food Security',
#      'prism:eIssn': '20487010',
#      'prism:volume': '12',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1186/s40066-023-00428-2',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Université de Liège',
#        'affiliation-city': 'Liege',
#        'affiliation-country': 'Belgium'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 're',
#      'subtypeDescription': 'Review',
#      'article-number': '22',
#      'source-id': '21100782678',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85168193533'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85168193533?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85168193533&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85168193533&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85168193533',
#      'dc:identifier': 'SCOPUS_ID:85168193533',
#      'eid': '2-s2.0-85168193533',
#      'dc:title': 'Irrigated barley–grass pea crop mixtures can revive soil microbial activities and alleviate salinity in desertic conditions of southern Morocco',
#      'dc:creator': 'Ashilenje D.S.',
#      'prism:publicationName': 'Scientific Reports',
#      'prism:eIssn': '20452322',
#      'prism:volume': '13',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1038/s41598-023-40337-9',
#      'citedby-count': '1',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'}],
#      'pubmed-id': '37580392',
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '13174',
#      'source-id': '21100200805',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'},
#        {'$': 'publisherfullgold'},
#        {'$': 'repository'},
#        {'$': 'repositoryvor'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#        {'$': 'Gold'},
#        {'$': 'Green'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85165680448'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85165680448?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85165680448&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85165680448&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85165680448',
#      'dc:identifier': 'SCOPUS_ID:85165680448',
#      'eid': '2-s2.0-85165680448',
#      'dc:title': 'Author Correction: Influence of El Niño on the variability of global shoreline position (Nature Communications, (2023), 14, 1, (3133), 10.1038/s41467-023-38742-9)',
#      'dc:creator': 'Almar R.',
#      'prism:publicationName': 'Nature Communications',
#      'prism:eIssn': '20411723',
#      'prism:volume': '14',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1038/s41467-023-40239-4',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': "Laboratoire d'Etudes en Géophysique et Océanographie Spatiales",
#        'affiliation-city': 'Toulouse',
#        'affiliation-country': 'France'}],
#      'pubmed-id': '37491424',
#      'prism:aggregationType': 'Journal',
#      'subtype': 'er',
#      'subtypeDescription': 'Erratum',
#      'article-number': '4460',
#      'source-id': '19700182758',
#      'openaccess': '1',
#      'openaccessFlag': True},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85164383366'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85164383366?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85164383366&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85164383366&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85164383366',
#      'dc:identifier': 'SCOPUS_ID:85164383366',
#      'eid': '2-s2.0-85164383366',
#      'dc:title': 'Polyphosphate fertilizer impacts the enzymatic and non-enzymatic antioxidant capacity of wheat plants grown under salinity',
#      'dc:creator': 'Loudari A.',
#      'prism:publicationName': 'Scientific Reports',
#      'prism:eIssn': '20452322',
#      'prism:volume': '13',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1038/s41598-023-38403-3',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Gembloux Agro-Bio Tech',
#        'affiliation-city': 'Gembloux',
#        'affiliation-country': 'Belgium'}],
#      'pubmed-id': '37433920',
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '11212',
#      'source-id': '21100200805',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'},
#        {'$': 'publisherfullgold'},
#        {'$': 'repository'},
#        {'$': 'repositoryvor'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#        {'$': 'Gold'},
#        {'$': 'Green'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85163430179'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85163430179?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85163430179&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85163430179&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S1674200123001177'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85163430179',
#      'dc:identifier': 'SCOPUS_ID:85163430179',
#      'eid': '2-s2.0-85163430179',
#      'dc:title': 'Development and assessment of algorithms for DEM-LES simulations of fluidized bed',
#      'dc:creator': 'El Hamra F.E.Z.',
#      'prism:publicationName': 'Particuology',
#      'prism:issn': '16742001',
#      'prism:eIssn': '22104291',
#      'prism:volume': '83',
#      'prism:pageRange': '241-257',
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1016/j.partic.2023.05.009',
#      'pii': 'S1674200123001177',
#      'citedby-count': '0',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'source-id': '10900153324',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85161948882'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85161948882?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85161948882&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85161948882&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85161948882',
#      'dc:identifier': 'SCOPUS_ID:85161948882',
#      'eid': '2-s2.0-85161948882',
#      'dc:title': 'Influence of El Niño on the variability of global shoreline position',
#      'dc:creator': 'Almar R.',
#      'prism:publicationName': 'Nature Communications',
#      'prism:eIssn': '20411723',
#      'prism:volume': '14',
#      'prism:issueIdentifier': '1',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-12-01',
#      'prism:coverDisplayDate': 'December 2023',
#      'prism:doi': '10.1038/s41467-023-38742-9',
#      'citedby-count': '1',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': "Laboratoire d'Etudes en Géophysique et Océanographie Spatiales",
#        'affiliation-city': 'Toulouse',
#        'affiliation-country': 'France'}],
#      'pubmed-id': '37308517',
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '3133',
#      'source-id': '19700182758',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'},
#        {'$': 'publisherfullgold'},
#        {'$': 'repository'},
#        {'$': 'repositoryvor'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#        {'$': 'Gold'},
#        {'$': 'Green'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85158071518'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85158071518?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85158071518&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85158071518&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85158071518',
#      'dc:identifier': 'SCOPUS_ID:85158071518',
#      'eid': '2-s2.0-85158071518',
#      'dc:title': 'Aphanothece sp. as promising biostimulant to alleviate heavy metals stress in Solanum lycopersicum L. by enhancing physiological, biochemical, and metabolic responses',
#      'dc:creator': 'Fal S.',
#      'prism:publicationName': 'Scientific Reports',
#      'prism:eIssn': '20452322',
#      'prism:volume': '13',
# ...
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85156275312?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85156275312&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85156275312&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85156275312',
#      'dc:identifier': 'SCOPUS_ID:85156275312',
#      'eid': '2-s2.0-85156275312',
#      'dc:title': 'Machine-Learning-Based Downscaling of Hourly ERA5-Land Air Temperature over Mountainous Regions',
#      'dc:creator': 'Sebbar B.E.',
#      'prism:publicationName': 'Atmosphere',
#      'prism:eIssn': '20734433',
#      'prism:volume': '14',
#      'prism:issueIdentifier': '4',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-04-01',
#      'prism:coverDisplayDate': 'April 2023',
#      'prism:doi': '10.3390/atmos14040610',
#      'citedby-count': '2',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Université Toulouse III - Paul Sabatier',
#        'affiliation-city': 'Toulouse',
#        'affiliation-country': 'France'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '610',
#      'source-id': '15838',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85156179261'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85156179261?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85156179261&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85156179261&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85156179261',
#      'dc:identifier': 'SCOPUS_ID:85156179261',
#      'eid': '2-s2.0-85156179261',
#      'dc:title': 'Anaerobic Digestion of Agricultural Waste Using Microbial Inocula: Performance and Characterization of Bacterial Communities Using 16S rRNA Sequencing Approach',
#      'dc:creator': 'Niya B.',
#      'prism:publicationName': 'Energies',
#      'prism:eIssn': '19961073',
#      'prism:volume': '16',
#      'prism:issueIdentifier': '8',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-04-01',
#      'prism:coverDisplayDate': 'April 2023',
#      'prism:doi': '10.3390/en16083300',
#      'citedby-count': '1',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Université Hassan 1er',
#        'affiliation-city': 'Settat',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Moroccan Foundation for Advanced Science Innovation and Research (MAScIR)',
#        'affiliation-city': 'Rabat',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '3300',
#      'source-id': '62932',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85156101550'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85156101550?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85156101550&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85156101550&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85156101550',
#      'dc:identifier': 'SCOPUS_ID:85156101550',
#      'eid': '2-s2.0-85156101550',
#      'dc:title': 'Fungal Strain as Biological Tool to Remove Genotoxicity Effect of Phenolic Compounds from Olive Mill Wastewater',
#      'dc:creator': 'Boutafda A.',
#      'prism:publicationName': 'Sustainability (Switzerland)',
#      'prism:eIssn': '20711050',
#      'prism:volume': '15',
#      'prism:issueIdentifier': '8',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-04-01',
#      'prism:coverDisplayDate': 'April 2023',
#      'prism:doi': '10.3390/su15086510',
#      'citedby-count': '1',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Université Cadi Ayyad',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '6510',
#      'source-id': '21100240100',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85148647696'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85148647696?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85148647696&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85148647696&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85148647696',
#      'dc:identifier': 'SCOPUS_ID:85148647696',
#      'eid': '2-s2.0-85148647696',
#      'dc:title': 'Enhancement of piezoelectric β-polymorph formation and properties of graphene oxide and PZT-incorporated in PVDF-HFP matrix for energy harvesting applications',
#      'dc:creator': 'Labihi S.',
#      'prism:publicationName': 'Polymer Composites',
#      'prism:issn': '02728397',
#      'prism:eIssn': '15480569',
#      'prism:volume': '44',
#      'prism:issueIdentifier': '4',
#      'prism:pageRange': '2296-2304',
#      'prism:coverDate': '2023-04-01',
#      'prism:coverDisplayDate': 'April 2023',
#      'prism:doi': '10.1002/pc.27245',
#      'citedby-count': '2',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Laboratoire Physique de la Matière Condensée',
#        'affiliation-city': 'Casablanca',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Higher School of Textile and Clothing Industries (ESITH)',
#        'affiliation-city': 'Casablanca',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'source-id': '14433',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85147885348'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85147885348?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147885348&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85147885348&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0753332223001816'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85147885348',
#      'dc:identifier': 'SCOPUS_ID:85147885348',
#      'eid': '2-s2.0-85147885348',
#      'dc:title': 'Phytochemical profile and antioxidant capacity, α-amylase and α-glucosidase inhibitory activities of Oxalis pes-caprae extracts in alloxan-induced diabetic mice',
#      'dc:creator': 'Kabach I.',
#      'prism:publicationName': 'Biomedicine and Pharmacotherapy',
#      'prism:issn': '07533322',
#      'prism:eIssn': '19506007',
#      'prism:volume': '160',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-04-01',
#      'prism:coverDisplayDate': 'April 2023',
#      'prism:doi': '10.1016/j.biopha.2023.114393',
#      'pii': 'S0753332223001816',
#      'citedby-count': '3',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Faculty of Sciences and Technologies',
#        'affiliation-city': 'Tangier',
#        'affiliation-country': 'Morocco'}],
#      'pubmed-id': '36774725',
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '114393',
#      'source-id': '28620',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85147733488'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85147733488?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147733488&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85147733488&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0167273823000255'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85147733488',
#      'dc:identifier': 'SCOPUS_ID:85147733488',
#      'eid': '2-s2.0-85147733488',
#      'dc:title': 'Enhancement of the Na<inf>2</inf>FePO<inf>4</inf>F@gC<inf>3</inf>N<inf>4</inf> electrochemical performance in view of its implementation in sodium-ion batteries',
#      'dc:creator': 'El Kacemi Z.',
#      'prism:publicationName': 'Solid State Ionics',
#      'prism:issn': '01672738',
#      'prism:volume': '392',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-04-01',
#      'prism:coverDisplayDate': 'April 2023',
#      'prism:doi': '10.1016/j.ssi.2023.116167',
#      'pii': 'S0167273823000255',
#      'citedby-count': '1',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'International University of Rabat',
#        'affiliation-city': 'Sale',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'MAScIR Foundation',
#        'affiliation-city': 'Rabat',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '116167',
#      'source-id': '29887',
#      'openaccess': '0',
#      'openaccessFlag': False},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85147667047'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85147667047?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85147667047&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85147667047&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'full-text',
#        '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0301926823000323'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85147667047',
#      'dc:identifier': 'SCOPUS_ID:85147667047',
#      'eid': '2-s2.0-85147667047',
#      'dc:title': 'Widespread Cadomian–Pan-African Ediacaran magmatism across the Moroccan Meseta: Implication for the geodynamic evolution of the NW Gondwana margin',
#      'dc:creator': 'Ouabid M.',
#      'prism:publicationName': 'Precambrian Research',
#      'prism:issn': '03019268',
#      'prism:volume': '387',
#      'prism:pageRange': None,
#      'prism:coverDate': '2023-04-01',
#      'prism:coverDisplayDate': 'April 2023',
#      'prism:doi': '10.1016/j.precamres.2023.106992',
#      'pii': 'S0301926823000323',
#      'citedby-count': '2',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Mohammed VI Polytechnic University',
#        'affiliation-city': 'Ben Guerir',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'article-number': '106992',
#      'source-id': '25755',
#      'openaccess': '1',
#      'openaccessFlag': True,
#      'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherhybridgold'}]},
#      'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#        {'$': 'Hybrid Gold'}]}},
#     {'@_fa': 'true',
#      'link': [{'@_fa': 'true',
#        '@ref': 'self',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85135278660'},
#       {'@_fa': 'true',
#        '@ref': 'author-affiliation',
#        '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85135278660?field=author,affiliation'},
#       {'@_fa': 'true',
#        '@ref': 'scopus',
#        '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85135278660&origin=inward'},
#       {'@_fa': 'true',
#        '@ref': 'scopus-citedby',
#        '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85135278660&origin=inward'}],
#      'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85135278660',
#      'dc:identifier': 'SCOPUS_ID:85135278660',
#      'eid': '2-s2.0-85135278660',
#      'dc:title': 'Isolation and Characterization of PGPR and Their Potenzial for Drought Alleviation in Barley Plants',
#      'dc:creator': 'Slimani A.',
#      'prism:publicationName': 'Gesunde Pflanzen',
#      'prism:issn': '03674223',
#      'prism:eIssn': '14390345',
#      'prism:volume': '75',
#      'prism:issueIdentifier': '2',
#      'prism:pageRange': '377-391',
#      'prism:coverDate': '2023-04-01',
#      'prism:coverDisplayDate': 'April 2023',
#      'prism:doi': '10.1007/s10343-022-00709-z',
#      'citedby-count': '8',
#      'affiliation': [{'@_fa': 'true',
#        'affilname': 'Faculté des Sciences Semlalia',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'},
#       {'@_fa': 'true',
#        'affilname': 'Université Cadi Ayyad',
#        'affiliation-city': 'Marakech',
#        'affiliation-country': 'Morocco'}],
#      'prism:aggregationType': 'Journal',
#      'subtype': 'ar',
#      'subtypeDescription': 'Article',
#      'source-id': '22034',
#      'openaccess': '0',
#      'openaccessFlag': False}]}}]

# %%
import pandas as pd

# Assuming json_data contains your JSON object
json_data = all_data

entries = json_data[0]['search-results']['entry']

# Extracting the information
data = []
for entry in entries:
    title = entry.get('dc:title')
    authors = entry.get('dc:creator')
    #source = entry.get('prism:publicationName')
    year = entry.get('prism:coverDate')[:4] if entry.get('prism:coverDate') else None
    citations = entry.get('citedby-count')
    
    data.append([title, authors, source, year, citations])

# Creating a pandas DataFrame
columns = ['Document title', 'Authors', 'Year', 'Citations']
df = pd.DataFrame(data, columns=columns)

# Now, df contains the extracted data as a pandas DataFrame
df
# Out:
#                                        Document title          Authors  \
# 0   Investigating the long-term stability of photo...      Essahili O.
# 1   Comparison of Optimal Sensor Placement Technic...     Mghazli M.O.
# 2   Multi-Agent Deep Reinforcement Learning for co...         Knari A.
# 3   Climate impact, institutional context, and nat...          Yoon H.
# 4   Effect of Bilayer Variation on the Properties ...        Aouadi K.
# 5   Energy efficiency and hygrothermal performance...     Es-sakali N.
# 6   Effect of alkaline leaching of phosphogypsum o...       Bounaga A.
# 7   Chlorophyll performances as an indicator of co...     El Hayany B.
# 8   Impact of agricultural input subsidy policy on...        Camara A.
# 9   XRF online analyzer for measurements of P<inf>...      Ben Amar I.
# 10  An interventional clinical trial investigating...         Rahim A.
# 11  Synthesis, characterization and uptake studies...    Bardovskyi R.
# 12  Passive treatment residues of mine drainage: M...    Mehdaoui H.Y.
# 13  Uncovering applicability of Navicula permitis ...       Elhamji S.
# 14  Continuous treatment of highly concentrated ta...  Lissaneddine A.
# 15  Design of acid-geopolymers based on clays by-p...       En-naji S.
# 16  Enabling simultaneous valorization of tannery ...       Delhali A.
# 17  Modeling genotype × environment × management i...       Mamassi A.
# 18  Irrigated barley–grass pea crop mixtures can r...   Ashilenje D.S.
# 19  Author Correction: Influence of El Niño on the...         Almar R.
# 20  Polyphosphate fertilizer impacts the enzymatic...       Loudari A.
# 21  Development and assessment of algorithms for D...  El Hamra F.E.Z.
# 22  Influence of El Niño on the variability of glo...         Almar R.
# 23  Aphanothece sp. as promising biostimulant to a...           Fal S.
# 24  Addressing sustainable energy intermittence fo...     Bouaboula H.
#
#                                                Source  Year Citations
# 0   Journal of Photochemistry and Photobiology A: ...  2024         0
# 1                  Lecture Notes in Civil Engineering  2024         0
# 2                                     Ad Hoc Networks  2024         0
# 3                       Journal of Business Venturing  2024         0
# 4                      Mechanisms and Machine Science  2024         0
# 5                                      Applied Energy  2023         0
# 6                    Science of the Total Environment  2023         1
# 7   International Journal of Recycling of Organic ...  2023         0
# 8                                  Economic Modelling  2023         0
# 9                                  Scientific Reports  2023         0
# 10                                 Scientific Reports  2023         0
# 11                               Minerals Engineering  2023         0
# 12                               Minerals Engineering  2023         0
# 13               Journal of Water Process Engineering  2023         0
# 14  Journal of Environmental Health Science and En...  2023         0
# 15                               Applied Clay Science  2023         0
# 16                                 Scientific Reports  2023         0
# 17                      Agriculture and Food Security  2023         0
# 18                                 Scientific Reports  2023         1
# 19                              Nature Communications  2023         0
# 20                                 Scientific Reports  2023         0
# 21                                       Particuology  2023         0
# 22                              Nature Communications  2023         1
# 23                                 Scientific Reports  2023         0
# 24                                     Energy Reports  2023         4

# %%
import requests

# Define your API key
api_key = '7762f59ce3b9cb9117c74958bab4202b'

# Define the Scopus article ID
article_id = '85168996421'

# Define the API endpoint URL
url = f'https://api.elsevier.com/content/subject/scopus?description={article_id}'

# Set the headers with your API key
headers = {
    'Accept': 'application/json',
    'X-ELS-APIKey': api_key,
}

# Make the GET request to the API
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse and use the response data
    data = response.json()
    print(data)
else:
    # Handle errors
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'subject-classifications': {'error': 'No results found'}}
